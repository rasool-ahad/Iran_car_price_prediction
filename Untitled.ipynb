# %% [markdown]
# #  Import packages

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from unidecode import unidecode

# %% [markdown]
# # Get the data

# %%
cars_df = pd.read_csv("cars.csv")

# %% [markdown]
# # Take quick look at data structure

# %%
cars_df.head(30)
# Out:
#       City  Model_Year      Color  Mileage                           Brand  \
# 0   Tehran        1376    نقره ای      532    نیسان، پاترول 4 در، 6 سیلندر
# 1   Tehran        1392       سفید   150000                CNG ،پیکان، وانت
# 2   Tehran        1399       سفید        0                  SE ،131 ،پراید
# 3   Tehran        1396       سفید    80000                  SE ،132 ،پراید
# 4   Tehran        1393    نقره ای    80000            پژو، GLX ،405 بنزینی
# 5   Tehran        1393       سفید    85000                 SD، V8 206 ،پژو
# 7   Tehran        1396       سفید   100000         1800cc اتوماتیک ،J5 ،جک
# 8   Tehran        1390       سفید      300                 پژو، 206، تیپ ۲
# 10  Tehran        1399       سفید    40000             EX ،تیبا، صندوق دار
# 11  Tehran        1390       سفید   377678                  SL ،131 ،پراید
# 12  Tehran        1396       سفید    80000                  SE ،131 ،پراید
# 13  Tehran        1393    خاکستری   135000                 پژو، 206، تیپ ۵
# 14  Tehran        1388  نوک مدادی   238000        پراید، صندوق دار، بنزینی
# 15  Tehran        1396        آبی    87000   ام وی ام، X22، اتوماتیک اسپرت
# 16  Tehran        1397       سفید    50000              دانگ فنگ، H30 کراس
# 17  Tehran        1395       سفید    94000            سمند، LX، EF7 بنزینی
# 18  Tehran        1397  سفید صدفی    48000              ریگان، کوپا، رویال
# 19  Tehran        1400       سفید        8               تیبا، هاچبک، پلاس
# 20  Tehran        1393       سفید      195             پیکان، وانت، بنزینی
# 21  Tehran        1393       سفید   300000          پراید، 131، دوگانه سوز
# 23  Tehran        1396       سفید    76000                  S6 ،بی  وای دی
# 24  Tehran        1384       مشکی   465241        پراید، صندوق دار، بنزینی
# 25  Tehran        1396       سفید    82000            سمند، LX، EF7 گازسوز
# 26  Tehran        1397       سفید     8000                  SE ،131 ،پراید
# 27  Tehran        1396       سفید   144000          برلیانس، H230، دنده ای
# 28  Tehran        1399       سفید    25000              EX ،ساینا، دنده ای
# 29  Tehran        1397       سفید    46000                 پژو، 206، تیپ ۲
# 30  Tehran        1400       سفید        0               LX TU5 ،پژو، پارس
# 31  Tehran        1390       سفید   165000             پژو، 207i، اتوماتیک
# 32  Tehran        1397       سفید    96000  ام وی ام، X22، اتوماتیک لاکچری
#
#                 Body_Condition        Price Engine_Condition  \
# 0                     تمام رنگ  235000000.0             سالم
# 1                 خط و خش جزیی  110000000.0              NaN
# 2            سالم و بی خط و خش          NaN              NaN
# 3            سالم و بی خط و خش  125500000.0             سالم
# 4            سالم و بی خط و خش  187000000.0             سالم
# 5                 خط و خش جزیی  215000000.0             سالم
# 7         رنگ شدگی، در ۲ ناحیه          NaN              NaN
# 8                       دوررنگ          NaN             سالم
# 10           سالم و بی خط و خش  160000000.0             سالم
# 11                      دوررنگ          NaN             سالم
# 12                خط و خش جزیی  135000000.0             سالم
# 13         رنگ شدگی در ۲ ناحیه  192000000.0             سالم
# 14      رنگ شدگی، در چند ناحیه          NaN             سالم
# 15        رنگ شدگی، در ۱ ناحیه  390000000.0             سالم
# 11  2022-03-12          پیروزی
# 12  2022-03-19            نصرت
# 13  2022-03-12           جیحون
# 14  2022-03-12       رباط کریم
# 15  2022-03-19            پونک
# 16  2022-03-12             طیب
# 17  2022-03-19        تهران سر
# 18  2022-03-12            آذری
# 19  2022-03-19            قرچک
# 20  2022-03-12           بومهن
# 21  2022-03-05          پیروزی
# 23  2022-03-05            جلفا
# 24  2022-03-19         شهر قدس
# 25  2022-03-19      سعادت آباد
# 26  2022-03-12       حسین آباد
# 27  2022-03-19          صادقیه
# 28  2022-03-05         مسعودیه
# 29  2022-03-26           تجریش
# 30  2022-03-19  تهرانپارس شرقی
# 31  2022-03-19         ستارخان
# 32  2022-03-26          ورامین

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56402 entries, 0 to 56401
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   56402 non-null  object
#  1   Model_Year             56402 non-null  object
#  2   Color                  56399 non-null  object
#  3   Mileage                56402 non-null  object
#  4   Brand                  56402 non-null  object
#  5   Body_Condition         54955 non-null  object
#  6   Price                  43306 non-null  float64
#  7   Engine_Condition       53853 non-null  object
#  8   Chassis_Condition      46407 non-null  object
#  9   Third_party_insurance  52407 non-null  object
#  10  Gearbox                52954 non-null  object
#  11  Selling_Method         52637 non-null  object
#  12  Time                   56402 non-null  object
#  13  Location               56402 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 6.0+ MB

# %% [markdown]
# ### make integer string persion numbers

# %%
cars_df = pd.read_csv("cars.csv")
cars_df["Model_Year"] = cars_df["Model_Year"].apply(unidecode)
cars_df = cars_df.loc[cars_df["Model_Year"].str.startswith("13") | cars_df["Model_Year"].str.startswith("14") ]
cars_df["Model_Year"] = cars_df["Model_Year"].apply(int)

cars_df["Mileage"] = cars_df["Mileage"].str.replace("٬" , "")
cars_df["Mileage"] = cars_df["Mileage"].apply(int)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51137 entries, 0 to 56401
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   51137 non-null  object
#  1   Model_Year             51137 non-null  int64
#  2   Color                  51134 non-null  object
#  3   Mileage                51137 non-null  int64
#  4   Brand                  51137 non-null  object
#  5   Body_Condition         49775 non-null  object
#  6   Price                  38888 non-null  float64
#  7   Engine_Condition       48808 non-null  object
#  8   Chassis_Condition      41612 non-null  object
#  9   Third_party_insurance  47625 non-null  object
#  10  Gearbox                47953 non-null  object
#  11  Selling_Method         47732 non-null  object
#  12  Time                   51137 non-null  object
#  13  Location               51137 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 5.9+ MB

# %%
import matplotlib.pyplot as plt
cars_df.hist(bins=20, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'Model_Year'}>,
#         <AxesSubplot:title={'center':'Mileage'}>],
#        [<AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Correlation

# %%
corr_matrix = cars_df.corr()
corr_matrix
# Out:
#             Model_Year   Mileage     Price
# Model_Year    1.000000 -0.651736  0.424331
# Mileage      -0.651736  1.000000 -0.344637
# Price         0.424331 -0.344637  1.000000

# %%
from pandas.plotting import scatter_matrix

attributes = ["Model_Year", "Mileage", "Price"]
scatter_matrix(cars_df[attributes], figsize=(12, 8))
# Out:
# array([[<AxesSubplot:xlabel='Model_Year', ylabel='Model_Year'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='Model_Year'>,
#         <AxesSubplot:xlabel='Price', ylabel='Model_Year'>],
#        [<AxesSubplot:xlabel='Model_Year', ylabel='Mileage'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='Mileage'>,
#         <AxesSubplot:xlabel='Price', ylabel='Mileage'>],
#        [<AxesSubplot:xlabel='Model_Year', ylabel='Price'>,
#         <AxesSubplot:xlabel='Mileage', ylabel='Price'>,
#         <AxesSubplot:xlabel='Price', ylabel='Price'>]], dtype=object)

# %%
cars_df["Price"]
# Out:
# 0        235000000.0
# 1        110000000.0
# 2                NaN
# 3        125500000.0
# 4        187000000.0
#             ...
# 56395    195000000.0
# 56396    380000000.0
# 56397     75000000.0
# 56400     37000000.0
# 56401    271500000.0
# Name: Price, Length: 51137, dtype: float64

# %%
cars_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51137 entries, 0 to 56401
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   City                   51137 non-null  object
#  1   Model_Year             51137 non-null  int64
#  2   Color                  51134 non-null  object
#  3   Mileage                51137 non-null  int64
#  4   Brand                  51137 non-null  object
#  5   Body_Condition         49775 non-null  object
#  6   Price                  38888 non-null  float64
#  7   Engine_Condition       48808 non-null  object
#  8   Chassis_Condition      41612 non-null  object
#  9   Third_party_insurance  47625 non-null  object
#  10  Gearbox                47953 non-null  object
#  11  Selling_Method         47732 non-null  object
#  12  Time                   51137 non-null  object
#  13  Location               51137 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 5.9+ MB

# %%
cars_df["Color"].value_counts()
# Out:
# سفید          28512
# نقره ای        4515
# مشکی           4206
# خاکستری        2655
# نوک مدادی      2237
# سفید صدفی      1761
# آبی            1670
# یشمی            880
# بژ              718
# زرد             580
# دلفینی          563
# سرمه ای         360
# نقرآبی          342
# سبز             334
# قرمز            241
# آلبالویی        211
# قهوه ای         198
# زیتونی          143
# طوسی            135
# ذغالی           120
# اطلسی           105
# عنابی           102
# مسی              83
# بادمجانی         82
# عدسی             65
# سربی             58
# بنفش             45
# زرشکی            44
# گیلاسی           44
# کرم              27
# نارنجی           21
# طلایی            21
# تیتانیوم         13
# خاکی             12
# کربن بلک         10
# پوست پیازی        8
# برنز              7
# موکا              6
# Name: Color, dtype: int64

# %%
cars_df ["Brand"]
# Out:
# 0            نیسان، پاترول 4 در، 6 سیلندر
# 1                        CNG ،پیکان، وانت
# 2                          SE ،131 ،پراید
# 3                          SE ،132 ،پراید
# 4                    پژو، GLX ،405 بنزینی
#                        ...
# 56395                کوییک، دنده ای، ساده
# 56396              رنو، تندر 90، اتوماتیک
# 56397                       پیکان، بنزینی
# 56400                       پیکان، بنزینی
# 56401    2000cc مزدا، وانت، کارا تک کابین
# Name: Brand, Length: 51137, dtype: object

# %%
cars_df.isnull().sum()
# Out:
# City                         0
# Model_Year                   0
# Color                        3
# Mileage                      0
# Brand                        0
# Body_Condition            1362
# Price                    12249
# Engine_Condition          2329
# Chassis_Condition         9525
# Third_party_insurance     3512
# Gearbox                   3184
# Selling_Method            3405
# Time                         0
# Location                     0
# dtype: int64
